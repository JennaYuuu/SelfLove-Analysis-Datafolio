# %%
import pandas as pd
from scipy import stats

# %%
final = pd.read_csv('final_FULLselflove_1129.csv')
AOD_full = pd.read_csv('AODvsnonAOD_GOldformodeling.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5,6,8,9,12,13,34,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
final_AOD = final.copy()

# %%
AOD_full
# Out:
#                                       Social Media Post  Not AOD specific
# 0     If you want to read #stories of #recovery from...                 1
# 1     Currently listening to 🎶🎵🎤🎧🎼🎸🎷🎺🥁 #musicislife ...                 1
# 2     “If you are putting the needs of your signific...                 1
# 3     Don't buy into the toxic diet culture bs you'r...                 1
# 4     This is an album about restoration after heart...                 1
# ...                                                 ...               ...
# 1847  I have never known strength like I do today, i...                 0
# 1848  "I simply had to believe in a Spirit of the Un...                 0
# 1849  Super Sober Saturday night 🤣\n  .\n  .\n  🐟💩\n...                 0
# 1850  Matching your shoes to the present? One step t...                 0
# 1851  ...betcha didn’t know how real the struggle 😱\...                 0
#
# [1852 rows x 2 columns]

# %%
AOD = AOD_full[AOD_full['Not AOD specific'] == 1]
AOD
# Out:
#                                      Social Media Post  Not AOD specific
# 0    If you want to read #stories of #recovery from...                 1
# 1    Currently listening to 🎶🎵🎤🎧🎼🎸🎷🎺🥁 #musicislife ...                 1
# 2    “If you are putting the needs of your signific...                 1
# 3    Don't buy into the toxic diet culture bs you'r...                 1
# 4    This is an album about restoration after heart...                 1
# ..                                                 ...               ...
# 954  Minute Morning Motivation \n  \n \n  Your valu...                 1
# 955  Listen, I don’t know how long it will take, I ...                 1
# 956  Take time this #weekend to notice all the #bea...                 1
# 957  I'm always in favor of discovering the magic w...                 1
# 958  Tears happy or sad, are a beautiful part of li...                 1
#
# [959 rows x 2 columns]

# %%
AOD['captions2'] = AOD['Social Media Post']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
AOD['captions2'] = AOD['Social Media Post'].str.replace('"', '')
AOD['captions2'] = AOD['captions2'].str.replace(' ', '')
AOD['captions2'] = AOD['captions2'].str.lower()
AOD['captions2'] = AOD['captions2'].str.strip(" ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
AOD['captions2']= AOD['captions2'].str.rstrip("\n")
AOD['captions2']= AOD['captions2'].str.rstrip(" ")
AOD['captions2']= AOD['captions2'].str.lstrip(" ")
AOD['captions2']= AOD['captions2'].str.lstrip()
AOD['captions2']= AOD['captions2'].str.rstrip()
AOD['captions2']= AOD['captions2'].str.strip()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import re
def punc_removal(text):
  no_punc = re.sub(r'[^\w\s]', '', str(text))
  return no_punc
AOD['captions2'] = AOD['captions2'].apply(punc_removal)
AOD['captions2']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 0      ifyouwanttoreadstoriesofrecoveryfromsevereemot...
# 1      currentlylisteningtomusicislifejdilladjquefema...
# 2      ifyouareputtingtheneedsofyoursignificantotherb...
# 3      dontbuyintothetoxicdietculturebsyourebeingsold...
# 4      thisisanalbumaboutrestorationafterheartbreak\n...
#                              ...
# 954    minutemorningmotivation\n\n\nyourvaluedoesntch...
# 955    listenidontknowhowlongitwilltakeidontknowhowit...
# 956    taketimethisweekendtonoticeallthebeautyaroundy...
# 957    imalwaysinfavorofdiscoveringthemagicwithinapla...
# 958    tearshappyorsadareabeautifulpartoflifetheyrepr...
# ...

# %%
final_AOD['captions2'] = final_AOD['captions'].str.replace('"', '')
final_AOD['captions2'] = final_AOD['captions2'].str.replace(' ', '')
final_AOD['captions2'] = final_AOD['captions2'].str.lower()
final_AOD['captions2'] = final_AOD['captions2'].str.strip(" ")
final_AOD['captions2'] = final_AOD['captions2'].str.rstrip("\n")
final_AOD['captions2'] = final_AOD['captions2'].str.rstrip(" ")
final_AOD['captions2'] = final_AOD['captions2'].str.lstrip(" ")
final_AOD['captions2'] = final_AOD['captions2'].str.lstrip()
final_AOD['captions2'] = final_AOD['captions2'].str.rstrip()
final_AOD['captions2'] = final_AOD['captions2'].str.strip()
final_AOD['captions2'] = final_AOD['captions2'].apply(punc_removal)
final_AOD['captions2']
# Out:
# 0         loveigearsvscosnapseedinstadailyindianphotogra...
# 1         cutestpuppiesforyouyourdogsinstapuppyglobepets...
# 2         after7kmjourneyinhillsoexcitedwithmy3cutefrien...
# 3         happynewyearpsychologymentalhealthlovetherapym...
# 4         happynewyeartoallmaythisyearfullofjoyhappiness...
#                                 ...
# 191767    talktoyourpartnerabouttherelationshipstheywitn...
# 191768    youdeservekindnessandloveandrespectbewithsomeo...
# 191769    bekindtoyourself\nrecoverysmartrecoverysoberso...
# 191770    dontjudgeabookbyitscoveryouneverknowwhatsomeon...
# 191771    becauseweallneedtoberemindedsometimesjustaremi...
# Name: captions2, Length: 191772, dtype: object

# %%
merged_df_inner = pd.merge(final_AOD, AOD, on='captions2')
len(merged_df_inner)
# Out:
# 833

# %%
merge_df = final_AOD.merge(AOD, how='left')
merge_df
# Out:
#         Unnamed: 0  Unnamed: 0.1  ...  Social Media Post  Not AOD specific
# 0                0             0  ...                NaN               NaN
# 1                1             1  ...                NaN               NaN
# 2                2             2  ...                NaN               NaN
# 3                3             3  ...                NaN               NaN
# 4                4             4  ...                NaN               NaN
# ...            ...           ...  ...                ...               ...
# 191767      191767        191767  ...                NaN               NaN
# 191768      191768        191768  ...                NaN               NaN
# 191769      191769        191769  ...                NaN               NaN
# 191770      191770        191770  ...                NaN               NaN
# 191771      191771        191771  ...                NaN               NaN
#
# [191772 rows x 44 columns]

# %%
merge_df['In nonAOD subsample'] = merge_df['Social Media Post'].notnull()*1
merge_df
# Out:
#         Unnamed: 0  Unnamed: 0.1  ...  Social Media Post  Not AOD specific
# 0                0             0  ...                NaN               NaN
# 1                1             1  ...                NaN               NaN
# 2                2             2  ...                NaN               NaN
# 3                3             3  ...                NaN               NaN
# 4                4             4  ...                NaN               NaN
# ...            ...           ...  ...                ...               ...
# 191767      191767        191767  ...                NaN               NaN
# 191768      191768        191768  ...                NaN               NaN
# 191769      191769        191769  ...                NaN               NaN
# 191770      191770        191770  ...                NaN               NaN
# 191771      191771        191771  ...                NaN               NaN
#
# [191772 rows x 44 columns]

# %%
merge_df.loc[37909, 'In nonAOD subsample'] = 1
merge_df.loc[21855, 'In nonAOD subsample'] = 0
merge_df.loc[104075, 'In nonAOD subsample'] = 1
merge_df.loc[120713, 'In nonAOD subsample'] = 0
merge_df.loc[120789, 'In nonAOD subsample'] = 1
merge_df.loc[131761, 'In nonAOD subsample'] = 1
merge_df.loc[45833, 'In nonAOD subsample'] = 0
merge_df.loc[138012, 'In nonAOD subsample'] = 1
merge_df.loc[140784, 'In nonAOD subsample'] = 1
merge_df.loc[146965, 'In nonAOD subsample'] = 1
merge_df.loc[161157, 'In nonAOD subsample'] = 1
merge_df.loc[188887, 'In nonAOD subsample'] = 1
merge_df.loc[76413, 'In nonAOD subsample'] = 1
merge_df.loc[95802, 'In nonAOD subsample'] = 1
merge_df.loc[33546, 'In nonAOD subsample'] = 1
merge_df.loc[38090, 'In nonAOD subsample'] = 1
merge_df.loc[165822, 'In nonAOD subsample'] = 1
merge_df.loc[81211, 'In nonAOD subsample'] = 0
merge_df.loc[120701, 'In nonAOD subsample'] = 1
merge_df.loc[183579, 'In nonAOD subsample'] = 1
merge_df.loc[159565, 'In nonAOD subsample'] = 1
merge_df.loc[112049, 'In nonAOD subsample'] = 1
merge_df.loc[139156, 'In nonAOD subsample'] = 1
merge_df.loc[126002, 'In nonAOD subsample'] = 1
merge_df.loc[119173, 'In nonAOD subsample'] = 1
merge_df.loc[42565, 'In nonAOD subsample'] = 1
merge_df.loc[189671, 'In nonAOD subsample'] = 1
merge_df.loc[92201, 'In nonAOD subsample'] = 1
#merge_df.loc[102796, 'In nonAOD subsample'] = 1
merge_df.loc[112906, 'In nonAOD subsample'] = 1
merge_df.loc[66682, 'In nonAOD subsample'] = 1
merge_df.loc[150001, 'In nonAOD subsample'] = 1
merge_df.loc[67721, 'In nonAOD subsample'] = 1
merge_df.loc[68827, 'In nonAOD subsample'] = 1
merge_df.loc[76575, 'In nonAOD subsample'] = 1
merge_df.loc[28837, 'In nonAOD subsample'] = 1
merge_df.loc[183712, 'In nonAOD subsample'] = 1
merge_df.loc[89839, 'In nonAOD subsample'] = 1
merge_df.loc[131620, 'In nonAOD subsample'] = 1
merge_df.loc[131470, 'In nonAOD subsample'] = 1
merge_df.loc[162920, 'In nonAOD subsample'] = 1
merge_df.loc[98412, 'In nonAOD subsample'] = 1
merge_df.loc[167434, 'In nonAOD subsample'] = 1
merge_df.loc[166786, 'In nonAOD subsample'] = 1
merge_df.loc[105131, 'In nonAOD subsample'] = 1
merge_df.loc[38590, 'In nonAOD subsample'] = 1
merge_df.loc[179152, 'In nonAOD subsample'] = 1
merge_df.loc[94119, 'In nonAOD subsample'] = 1
merge_df.loc[103118, 'In nonAOD subsample'] = 1
merge_df.loc[38983, 'In nonAOD subsample'] = 1
merge_df.loc[82064, 'In nonAOD subsample'] = 1
merge_df.loc[158736, 'In nonAOD subsample'] = 1
merge_df.loc[83025, 'In nonAOD subsample'] = 1
merge_df.loc[108887, 'In nonAOD subsample'] = 1
merge_df.loc[102268, 'In nonAOD subsample'] = 1
merge_df.loc[54076, 'In nonAOD subsample'] = 1
merge_df.loc[24127, 'In nonAOD subsample'] = 1
merge_df.loc[113005, 'In nonAOD subsample'] = 1
merge_df.loc[78953, 'In nonAOD subsample'] = 1
merge_df.loc[21857, 'In nonAOD subsample'] = 1
merge_df.loc[139775, 'In nonAOD subsample'] = 1
merge_df.loc[181367, 'In nonAOD subsample'] = 1
merge_df.loc[36381, 'In nonAOD subsample'] = 1
merge_df.loc[108039, 'In nonAOD subsample'] = 1
merge_df.loc[116181, 'In nonAOD subsample'] = 1
merge_df.loc[190012, 'In nonAOD subsample'] = 1
merge_df.loc[85286, 'In nonAOD subsample'] = 1
merge_df.loc[19400, 'In nonAOD subsample'] = 1
merge_df.loc[184725, 'In nonAOD subsample'] = 1
merge_df.loc[69293, 'In nonAOD subsample'] = 1
merge_df.loc[94416, 'In nonAOD subsample'] = 1
merge_df.loc[46669, 'In nonAOD subsample'] = 1
merge_df.loc[111018, 'In nonAOD subsample'] = 1
merge_df.loc[151274, 'In nonAOD subsample'] = 1
merge_df.loc[145270, 'In nonAOD subsample'] = 1
merge_df.loc[42743, 'In nonAOD subsample'] = 1
merge_df.loc[48765, 'In nonAOD subsample'] = 1
merge_df.loc[165419, 'In nonAOD subsample'] = 1
merge_df.loc[111211, 'In nonAOD subsample'] = 1
merge_df.loc[182895, 'In nonAOD subsample'] = 1
merge_df.loc[71322, 'In nonAOD subsample'] = 1
merge_df.loc[54704, 'In nonAOD subsample'] = 1
merge_df.loc[109854, 'In nonAOD subsample'] = 1
merge_df.loc[154795, 'In nonAOD subsample'] = 1
merge_df.loc[140595, 'In nonAOD subsample'] = 1
merge_df.loc[154282, 'In nonAOD subsample'] = 1
merge_df.loc[58628, 'In nonAOD subsample'] = 1
merge_df.loc[172732, 'In nonAOD subsample'] = 1
merge_df.loc[56488, 'In nonAOD subsample'] = 1
merge_df.loc[185381, 'In nonAOD subsample'] = 1
merge_df.loc[31282, 'In nonAOD subsample'] = 1
merge_df.loc[161511, 'In nonAOD subsample'] = 1
merge_df.loc[87304, 'In nonAOD subsample'] = 1
merge_df.loc[82503, 'In nonAOD subsample'] = 1
merge_df.loc[184477, 'In nonAOD subsample'] = 1
merge_df.loc[170749, 'In nonAOD subsample'] = 1
merge_df.loc[156469, 'In nonAOD subsample'] = 1
merge_df.loc[80339, 'In nonAOD subsample'] = 1
merge_df.loc[28149, 'In nonAOD subsample'] = 1
merge_df.loc[164162, 'In nonAOD subsample'] = 1
merge_df.loc[136356, 'In nonAOD subsample'] = 1
merge_df.loc[82650, 'In nonAOD subsample'] = 1
merge_df.loc[68480, 'In nonAOD subsample'] = 1
merge_df.loc[84126, 'In nonAOD subsample'] = 1
merge_df.loc[160005, 'In nonAOD subsample'] = 1
merge_df.loc[86517, 'In nonAOD subsample'] = 1
merge_df.loc[168409, 'In nonAOD subsample'] = 1
merge_df.loc[179053, 'In nonAOD subsample'] = 1
merge_df.loc[162913, 'In nonAOD subsample'] = 1
merge_df.loc[137545, 'In nonAOD subsample'] = 1
merge_df.loc[102533, 'In nonAOD subsample'] = 1
merge_df.loc[72149, 'In nonAOD subsample'] = 1
merge_df.loc[93364, 'In nonAOD subsample'] = 1
merge_df.loc[137396, 'In nonAOD subsample'] = 1
merge_df.loc[111484, 'In nonAOD subsample'] = 1
merge_df.loc[146906, 'In nonAOD subsample'] = 1
merge_df.loc[128654, 'In nonAOD subsample'] = 1
merge_df.loc[130480, 'In nonAOD subsample'] = 1
merge_df.loc[20074, 'In nonAOD subsample'] = 1
merge_df.loc[181348, 'In nonAOD subsample'] = 1
merge_df.loc[173904, 'In nonAOD subsample'] = 1
merge_df.loc[154082, 'In nonAOD subsample'] = 1
merge_df.loc[57458, 'In nonAOD subsample'] = 1
merge_df.loc[73264, 'In nonAOD subsample'] = 1
merge_df.loc[102520, 'In nonAOD subsample'] = 1
merge_df.loc[57219, 'In nonAOD subsample'] = 1
merge_df.loc[27083, 'In nonAOD subsample'] = 1
merge_df.loc[176012, 'In nonAOD subsample'] = 1
merge_df.loc[60162, 'In nonAOD subsample'] = 1
merge_df.loc[77817, 'In nonAOD subsample'] = 1
merge_df.loc[105131, 'In nonAOD subsample'] = 1
merge_df.loc[70431, 'In nonAOD subsample'] = 1
merge_df.loc[177568, 'In nonAOD subsample'] = 1

# %%
merge_df.iloc[177568]
# Out:
# Unnamed: 0                                                                                     177568
# Unnamed: 0.1                                                                                   177568
# Unnamed: 0.1.1                                                                                 177569
# Unnamed: 0.1.1.1                                                                               177569
# name                                                                                              NaN
# id                                                                                        2.47891e+09
# post_id                                                                                       1.2e+18
# captions                                            Akira says:\n\n“Thank you for your compassion....
# image name                                                                                        NaN
# ...

# %%
merge_df
# Out:
#         Unnamed: 0  Unnamed: 0.1  ...  Social Media Post  Not AOD specific
# 0                0             0  ...                NaN               NaN
# 1                1             1  ...                NaN               NaN
# 2                2             2  ...                NaN               NaN
# 3                3             3  ...                NaN               NaN
# 4                4             4  ...                NaN               NaN
# ...            ...           ...  ...                ...               ...
# 191767      191767        191767  ...                NaN               NaN
# 191768      191768        191768  ...                NaN               NaN
# 191769      191769        191769  ...                NaN               NaN
# 191770      191770        191770  ...                NaN               NaN
# 191771      191771        191771  ...                NaN               NaN
#
# [191772 rows x 44 columns]

# %%
finalwithnonAOD = merge_df.drop(columns=['captions2', 'Social Media Post','Not AOD specific'])
finalwithnonAOD
# Out:
#         Unnamed: 0  ...  In nonAOD subsample
# 0                0  ...                    0
# 1                1  ...                    0
# 2                2  ...                    0
# 3                3  ...                    0
# 4                4  ...                    0
# ...            ...  ...                  ...
# 191767      191767  ...                    0
# 191768      191768  ...                    0
# 191769      191769  ...                    0
# 191770      191770  ...                    0
# 191771      191771  ...                    0
#
# [191772 rows x 41 columns]

# %%
from google.colab import files

finalwithnonAOD.to_csv('final_with_nonAOD.csv')
files.download('final_with_nonAOD.csv')

# %%
AOD_matched = merged_df_inner[['captions','captions2','Social Media Post', 'Not AOD specific']]
AOD_matched = AOD_matched[['captions','Social Media Post', 'Not AOD specific','captions2']]
AOD_matched
# Out:
#                                               captions  ...                                          captions2
# 0    #growingupblack #growingupagirl #lifestyle #li...  ...  growingupblackgrowingupagirllifestylelifestyle...
# 1    #moroccotravel #tamazirt #enjoy #bestmoments #...  ...  moroccotraveltamazirtenjoybestmomentsfriendtan...
# 2    🌊🌊 #moroccotravel #tamazirt #enjoy #bestmoment...  ...  moroccotraveltamazirtenjoybestmomentsfriendtan...
# 3    💪🏻😍😍 #moroccotravel #tamazirt #enjoy #bestmome...  ...  moroccotraveltamazirtenjoybestmomentsfriendtan...
# 4    👌🏻💯✅✅ #moroccotravel #tamazirt #enjoy #bestmom...  ...  moroccotraveltamazirtenjoybestmomentsfriendtan...
# ..                                                 ...  ...                                                ...
# 827  She knows she has an irresistible pussy.... he...  ...  sheknowsshehasanirresistiblepussyherownfingers...
# ...

# %%
df3 = pd.merge(AOD_matched,AOD, left_on=["captions2"], 
               right_on=["captions2"],
               how='outer', indicator=True)

unmatched = df3.query('_merge == "right_only"')
unmatched
# Out:
#     captions Social Media Post_x  ...  Not AOD specific_y      _merge
# 832      NaN                 NaN  ...                   1  right_only
# 833      NaN                 NaN  ...                   1  right_only
# 834      NaN                 NaN  ...                   1  right_only
# 835      NaN                 NaN  ...                   1  right_only
# 836      NaN                 NaN  ...                   1  right_only
# ..       ...                 ...  ...                 ...         ...
# 981      NaN                 NaN  ...                   1  right_only
# 982      NaN                 NaN  ...                   1  right_only
# 983      NaN                 NaN  ...                   1  right_only
# 984      NaN                 NaN  ...                   1  right_only
# 985      NaN                 NaN  ...                   1  right_only
#
# [154 rows x 7 columns]

# %%
AOD_matched.to_csv('matched_non_AOD_posts.csv')
files.download('matched_non_AOD_posts.csv')

# %%
from google.colab import files

unmatched.to_csv('unmatched_non_AOD_posts.csv')
files.download('unmatched_non_AOD_posts.csv')

# %%
merge_df.to_csv('merge_df.csv')
files.download('merge_df.csv')
